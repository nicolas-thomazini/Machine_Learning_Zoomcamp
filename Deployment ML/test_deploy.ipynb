# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import requests

# %%
customer = {
    'customerid': '8879-zkjof',
    'gender': 'male',
    'seniorcitizen': 0,
    'partner': 'yes',
    'dependents': 'yes',
    'tenure': 2,
    'phoneservice': 'yes',
    'multiplelines': 'yes',
    'internetservice': 'dsl',
    'onlinesecurity': 'yes',
    'onlinebackup': 'no',
    'deviceprotection': 'yes',
    'techsupport': 'yes',
    'streamingtv': 'yes',
    'streamingmovies': 'yes',
    'contract': 'one_year',
    'paperlessbilling': 'yes',
    'paymentmethod': 'bank_transfer_(automatic)',
    'monthlycharges': 109.85,
    'totalcharges': 5320.75
}

# %%
url = 'http://localhost:9696/predict'

# %%
response = requests.post(url, json=customer).json()
response
# Out:
# {'churn': True, 'churn_probability': 0.6514692904560347}

# %%
if response['churn'] == True:
    print('sending promo email to %s' % ('xyz-123'))
# Out:
# sending promo email to xyz-123
